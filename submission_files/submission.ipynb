# %% [markdown]
# [Repo URL](https://github.com/ralahaaqil/dsci-522-individual-assignment-quarto-python)
#
# [GitHub pages URL](https://ralahaaqil.github.io/dsci-522-individual-assignment-quarto-python/)
